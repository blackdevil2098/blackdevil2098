# %% [markdown]
# <a href="https://colab.research.google.com/github/blackdevil2098/blackdevil2098/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/gdrive/MyDrive/ML/battles.csv")
df.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       36 non-null     object
#  4   defender_king       35 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          10 non-null     object
#  7   attacker_3          3 non-null      object
#  8   attacker_4          2 non-null      object
#  9   defender_1          37 non-null     object
#  10  defender_2          2 non-null      object
#  11  defender_3          0 non-null      float64
#  12  defender_4          0 non-null      float64
#  13  attacker_outcome    37 non-null     object
#  14  battle_type         37 non-null     object
# ...

# %%
df.shape
# Out:
# (38, 25)

# %%
to_drop = ['attacker_3',
          'attacker_4', 
          'defender_2',
          'defender_3',
          'defender_4', 
          'note']
df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       36 non-null     object
#  4   defender_king       35 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          10 non-null     object
#  7   attacker_3          3 non-null      object
#  8   attacker_4          2 non-null      object
#  9   defender_1          37 non-null     object
#  10  defender_2          2 non-null      object
#  11  defender_3          0 non-null      float64
#  12  defender_4          0 non-null      float64
#  13  attacker_outcome    37 non-null     object
#  14  battle_type         37 non-null     object
# ...

# %%
df = df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       38 non-null     object
#  4   defender_king       38 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          38 non-null     object
#  7   attacker_3          38 non-null     object
#  8   attacker_4          38 non-null     object
#  9   defender_1          38 non-null     object
#  10  defender_2          38 non-null     object
#  11  defender_3          38 non-null     float64
#  12  defender_4          38 non-null     float64
#  13  attacker_outcome    38 non-null     object
#  14  battle_type         38 non-null     object
# ...

# %%
df.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands    0
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands    0
# 2             Battle of Riverrun   298  ...   The Riverlands    0
# 3       Battle of the Green Fork   298  ...   The Riverlands    0
# 4  Battle of the Whispering Wood   298  ...   The Riverlands    0
#
# [5 rows x 25 columns]

# %%
df.region.unique()
# Out:
# array(['The Westerlands', 'The Riverlands', 'The North', 'The Stormlands',
#        'The Crownlands', 'Beyond the Wall', 'The Reach'], dtype=object)

# %%
joff = df.loc[df['attacker_king'] == 'Joffrey/Tommen Baratheon']
joff.head()
# Out:
#                            name  ...                                               note
# 0    Battle of the Golden Tooth  ...                                                  0
# 1   Battle at the Mummer's Ford  ...                                                  0
# 2            Battle of Riverrun  ...                                                  0
# 6                 Sack of Darry  ...                                                  0
# 13           Sack of Winterfell  ...  Since House Bolton betrays the Starks for Hous...
#
# [5 rows x 25 columns]

# %%
joff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 0 to 36
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                14 non-null     object
#  1   year                14 non-null     int64
#  2   battle_number       14 non-null     int64
#  3   attacker_king       14 non-null     object
#  4   defender_king       14 non-null     object
#  5   attacker_1          14 non-null     object
#  6   attacker_2          14 non-null     object
#  7   attacker_3          14 non-null     object
#  8   attacker_4          14 non-null     object
#  9   defender_1          14 non-null     object
#  10  defender_2          14 non-null     object
#  11  defender_3          14 non-null     float64
#  12  defender_4          14 non-null     float64
#  13  attacker_outcome    14 non-null     object
#  14  battle_type         14 non-null     object
# ...

# %%
win = joff.attacker_outcome.value_counts()['win']
loss = joff.attacker_outcome.value_counts()['loss']
print(win, loss)
# Out:
# 13 1

# %%
joff.loc[joff['attacker_outcome'] == 'loss']
# Out:
#                    name  year  battle_number  ...  location          region note
# 16  Battle of the Fords   299             17  ...  Red Fork  The Riverlands    0
#
# [1 rows x 25 columns]

# %%
joff.battle_type.unique()
# Out:
# array(['pitched battle', 'ambush', 'siege'], dtype=object)

# %%
joff.loc[joff['battle_type'] == 'pitched battle']
# Out:
#                           name  year  ...           region note
# 0   Battle of the Golden Tooth   298  ...  The Westerlands    0
# 2           Battle of Riverrun   298  ...   The Riverlands    0
# 6                Sack of Darry   298  ...   The Riverlands    0
# 16         Battle of the Fords   299  ...   The Riverlands    0
# 23     Battle of the Ruby Ford   299  ...   The Riverlands    0
# 24       Retaking of Harrenhal   299  ...   The Riverlands    0
#
# [6 rows x 25 columns]

# %%
joff.loc[joff['battle_type'] == 'ambush']
# Out:
#                            name  ...                                               note
# 1   Battle at the Mummer's Ford  ...                                                  0
# 13           Sack of Winterfell  ...  Since House Bolton betrays the Starks for Hous...
# 25              The Red Wedding  ...  This observation refers to the battle against ...
#
# [3 rows x 25 columns]

# %%
joff.loc[joff['battle_type'] == 'siege']
# Out:
#                            name  year  ...          region note
# 28          Fall of Moat Cailin   300  ...       The North    0
# 33  Second Seige of Storm's End   300  ...  The Stormlands    0
# 34         Siege of Dragonstone   300  ...  The Stormlands    0
# 35            Siege of Riverrun   300  ...  The Riverlands    0
# 36           Siege of Raventree   300  ...  The Riverlands    0
#
# [5 rows x 25 columns]

# %%
x = joff.battle_type.value_counts()
x
# Out:
# pitched battle    6
# siege             5
# ambush            3
# Name: battle_type, dtype: int64

# %%
sns.countplot(x=joff.attacker_king, hue=joff.battle_type)
plt.xlabel("Iron Throne")
plt.ylabel("Count")
plt.show()

# %%
sns.barplot(x="defender_king", y="defender_size", data=joff)
plt.title("Defender King vs Size of Army")
plt.xlabel("Defender King")
plt.ylabel("Army Size")
plt.xticks(rotation=15)
plt.show()

# %%
joff.loc[joff['defender_king'] == 0]
# Out:
#                      name  year  battle_number  ...   location          region note
# 24  Retaking of Harrenhal   299             25  ...  Harrenhal  The Riverlands    0
#
# [1 rows x 25 columns]

# %%
joff.loc[joff['defender_king'] == 'Balon/Euron Greyjoy']
# Out:
#                    name  year  battle_number  ...     location     region note
# 28  Fall of Moat Cailin   300             29  ...  Moat Cailin  The North    0
#
# [1 rows x 25 columns]
